# %%
import os
import copy
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from itertools import zip_longest
from collections import defaultdict

import torch
from torch import nn
from torch import optim
from torch.nn import functional as F 
from torch.optim.lr_scheduler import _LRScheduler, LambdaLR
from torch.optim import Adam

from scipy.sparse import coo_matrix
from scipy.sparse import vstack
from scipy import sparse

from torch.utils.data import random_split, DataLoader

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)

RANDOM_STATE=24

def read_data(path):
    files = {}
    for filename in os.listdir(path):
        if filename.endswith('.csv'):
            files[filename[:-4]] = pd.read_csv(path + '/' + filename)
        else:
            print('need csv file type')
    return files['ratings'], files['movies']
# Out:
# cuda:0

# %%
ratings, movies = read_data('data-small')
# Out:
# need csv file type
# need csv file type

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# get max for each
userNum = ratings['userId'].max()
itemNum = ratings['movieId'].max()

# %%
# for 0 indexing
ratings['userId'] = ratings['userId'] - 1
ratings['movieId'] = ratings['movieId'] - 1

# %%
# RMSE: comparison of two models for recommendations
# NGCF dim = 64 layer = [64,64,64] nn = [128,64,32,] 50 epoch RMSE = 0.916/RMSE =0.914
# NCF dim = 64 50 nn = [128,54,32] epoch 50 RMSE = 0.928

class NCF(nn.Module):
    def __init__(self,userNum,itemNum,dim,layers=[128,64,32,8]):
        super(NCF, self).__init__()
        self.uEmbd = nn.Embedding(userNum,dim)
        self.iEmbd = nn.Embedding(itemNum,dim)
        self.fc_layers = torch.nn.ModuleList()
        self.finalLayer = torch.nn.Linear(layers[-1],1)

        for From,To in zip(layers[:-1],layers[1:]):
            self.fc_layers.append(nn.Linear(From,To))

    def forward(self, userIdx,itemIdx):
        uembd = self.uEmbd(userIdx)
        iembd = self.iEmbd(itemIdx)
        embd = torch.cat([uembd, iembd], dim=1)
        x = embd
        for l in self.fc_layers:
            x = l(x)
            x = nn.ReLU()(x)

        prediction = self.finalLayer(x)
        return prediction.flatten()


class GNNLayer(nn.Module):
    def __init__(self,inF,outF):

        super(GNNLayer,self).__init__()
        self.inF = inF
        self.outF = outF
        self.linear = torch.nn.Linear(in_features=inF,out_features=outF)
        self.interActTransform = torch.nn.Linear(in_features=inF,out_features=outF)

    def forward(self, laplacianMat,selfLoop,features):
        # for GCF ajdMat is a (N+M) by (N+M) mat
        # laplacianMat L = D^-1(A)D^-1
        L1 = laplacianMat + selfLoop
        L2 = laplacianMat.cuda()
        L1 = L1.cuda()
        inter_feature = torch.sparse.mm(L2,features)
        inter_feature = torch.mul(inter_feature,features)

        inter_part1 = self.linear(torch.sparse.mm(L1,features))
        inter_part2 = self.interActTransform(torch.sparse.mm(L2,inter_feature))

        return inter_part1+inter_part2

class GCF(nn.Module):

    def __init__(self,userNum,itemNum,rt,embedSize=100,layers=[100,80,50],useCuda=True):

        super(GCF,self).__init__()
        self.useCuda = useCuda
        self.userNum = userNum
        self.itemNum = itemNum
        self.uEmbd = nn.Embedding(userNum,embedSize)
        self.iEmbd = nn.Embedding(itemNum,embedSize)
        self.GNNlayers = torch.nn.ModuleList()
        self.LaplacianMat = self.buildLaplacianMat(rt) # sparse format
        self.leakyRelu = nn.LeakyReLU()
        self.selfLoop = self.getSparseEye(self.userNum+self.itemNum)

        self.transForm1 = nn.Linear(in_features=layers[-1]*(len(layers))*2,out_features=64)
        self.transForm2 = nn.Linear(in_features=64,out_features=32)
        self.transForm3 = nn.Linear(in_features=32,out_features=1)

        for From,To in zip(layers[:-1],layers[1:]):
            self.GNNlayers.append(GNNLayer(From,To))

    def getSparseEye(self,num):
        i = torch.LongTensor([[k for k in range(0,num)],[j for j in range(0,num)]])
        val = torch.FloatTensor([1]*num)
        return torch.sparse.FloatTensor(i,val)

    def buildLaplacianMat(self,rt):

        rt_item = rt['movieId'] + self.userNum
        uiMat = coo_matrix((rt['rating'], (rt['userId'], rt['movieId'])))

        uiMat_upperPart = coo_matrix((rt['rating'], (rt['userId'], rt_item)))
        uiMat = uiMat.transpose()
        uiMat.resize((self.itemNum, self.userNum + self.itemNum))

        A = sparse.vstack([uiMat_upperPart,uiMat])
        selfLoop = sparse.eye(self.userNum+self.itemNum)
        sumArr = (A>0).sum(axis=1)
        diag = list(np.array(sumArr.flatten())[0])
        diag = np.power(diag,-0.5)
        D = sparse.diags(diag)
        L = D * A * D
        L = sparse.coo_matrix(L)
        row = L.row
        col = L.col
        i = torch.LongTensor([row,col])
        data = torch.FloatTensor(L.data)
        SparseL = torch.sparse.FloatTensor(i,data)
        return SparseL

    def getFeatureMat(self):
        uidx = torch.LongTensor([i for i in range(self.userNum)])
        iidx = torch.LongTensor([i for i in range(self.itemNum)])
        if self.useCuda == True:
            uidx = uidx.cuda()
            iidx = iidx.cuda()

        userEmbd = self.uEmbd(uidx)
        itemEmbd = self.iEmbd(iidx)
        features = torch.cat([userEmbd,itemEmbd],dim=0)
        return features

    def forward(self,userIdx,itemIdx):

        itemIdx = itemIdx + self.userNum
        userIdx = list(userIdx.cpu().data)
        itemIdx = list(itemIdx.cpu().data)
        # gcf data propagation
        features = self.getFeatureMat()
        finalEmbd = features.clone()
        for gnn in self.GNNlayers:
            features = gnn(self.LaplacianMat,self.selfLoop,features)
            features = nn.ReLU()(features)
            finalEmbd = torch.cat([finalEmbd,features.clone()],dim=1)

        userEmbd = finalEmbd[userIdx]
        itemEmbd = finalEmbd[itemIdx]
        embd = torch.cat([userEmbd,itemEmbd],dim=1)

        embd = nn.ReLU()(self.transForm1(embd))
        embd = self.transForm2(embd)
        embd = self.transForm3(embd)
        prediction = embd.flatten()

        return prediction

# %%
from torch.utils.data import Dataset

# movielens 1k

class ML1K(Dataset):

    def __init__(self,rt):
        super(Dataset,self).__init__()
        self.uId = list(rt['userId'])
        self.iId = list(rt['movieId'])
        self.rt = list(rt['rating'])

    def __len__(self):
        return len(self.uId)

    def __getitem__(self, item):
        return (self.uId[item],self.iId[item],self.rt[item])

# %%
para = {
    'epoch':60,
    'lr':0.01,
    'batch_size':2048,
    'train':0.8
}

ds = ML1K(ratings)
trainLen = int(para['train']*len(ds))
train,test = random_split(ds,[trainLen,len(ds)-trainLen])
dl = DataLoader(train,batch_size=para['batch_size'],shuffle=True,pin_memory=True)

model = GCF(userNum, itemNum, ratings, 80, layers=[80,80,]).cuda()
# model = SVD(userNum,itemNum,50).cuda()
# model = NCF(userNum,itemNum,64,layers=[128,64,32,16,8]).cuda()
optim = Adam(model.parameters(), lr=para['lr'],weight_decay=0.001)
lossfn = nn.MSELoss()

for i in range(para['epoch']):

    for id,batch in enumerate(dl):
        print('epoch:',i,' batch:',id)
        optim.zero_grad()
        prediction = model(batch[0].cuda(), batch[1].cuda())
        loss = lossfn(batch[2].float().cuda(),prediction)
        loss.backward()
        optim.step()
        print(loss)


testdl = DataLoader(test,batch_size=len(test),)
for data in testdl:
    prediction = model(data[0].cuda(),data[1].cuda())

loss = lossfn(data[2].float().cuda(),prediction)
print(loss) # MSEloss
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:92: RuntimeWarning: divide by zero encountered in power
# epoch: 0  batch: 0
# tensor(15.1574, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 1
# tensor(7.5563, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 2
# tensor(2.4537, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 3
# tensor(4.9623, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 4
# tensor(1.2459, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 5
# tensor(2.1806, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 6
# tensor(3.0910, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 7
# tensor(2.6030, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 8
# tensor(1.7631, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 9
# tensor(1.3651, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 10
# tensor(1.8898, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 11
# tensor(1.9280, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 12
# tensor(1.3234, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 13
# tensor(1.1531, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 14
# tensor(1.2482, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 15
# tensor(1.4060, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 16
# tensor(1.3830, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 17
# tensor(1.1443, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 18
# tensor(1.1046, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 19
# tensor(1.2499, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 20
# tensor(1.1904, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 21
# tensor(1.1015, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 22
# tensor(0.9646, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 23
# tensor(0.9488, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 24
# tensor(1.0990, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 25
# tensor(1.0776, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 26
# tensor(1.0207, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 27
# tensor(0.9341, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 28
# tensor(0.9686, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 29
# tensor(0.9893, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 30
# tensor(0.9575, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 31
# tensor(0.9413, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 32
# tensor(0.8838, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 33
# tensor(0.9612, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 34
# tensor(0.9519, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 35
# tensor(0.8880, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 36
# tensor(0.8941, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 37
# tensor(0.8767, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 38
# tensor(0.9192, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 0  batch: 39
# tensor(0.9112, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 0
# tensor(0.8401, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 1
# tensor(0.8752, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 2
# tensor(0.7927, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 3
# tensor(0.8108, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 4
# tensor(0.8637, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 5
# tensor(0.8123, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 6
# tensor(0.8554, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 7
# tensor(0.8565, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 8
# tensor(0.8027, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 9
# tensor(0.8505, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 10
# tensor(0.8376, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 11
# tensor(0.8810, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 12
# tensor(0.8605, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 13
# tensor(0.7387, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 14
# tensor(0.7784, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 15
# tensor(0.8783, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 16
# tensor(0.8234, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 17
# tensor(0.8514, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 18
# tensor(0.8096, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 19
# tensor(0.8296, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 20
# tensor(0.8455, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 21
# tensor(0.8320, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 22
# tensor(0.9037, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 23
# tensor(0.8287, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 24
# tensor(0.8324, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 25
# tensor(0.8342, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 26
# tensor(0.8071, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 27
# tensor(0.7674, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 28
# tensor(0.8008, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 29
# tensor(0.8534, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 30
# tensor(0.8214, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 31
# tensor(0.8052, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 32
# tensor(0.7988, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 33
# tensor(0.7925, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 34
# tensor(0.8142, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 35
# tensor(0.8048, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 36
# tensor(0.8003, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 37
# tensor(0.8317, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 38
# tensor(0.7908, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 1  batch: 39
# tensor(0.8657, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 0
# tensor(0.7769, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 1
# tensor(0.7428, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 2
# tensor(0.7460, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 3
# tensor(0.7970, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 4
# tensor(0.8090, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 5
# tensor(0.7634, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 6
# tensor(0.8144, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 7
# tensor(0.8181, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 8
# tensor(0.8066, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 9
# tensor(0.7973, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 10
# tensor(0.8185, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 11
# tensor(0.7513, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 12
# tensor(0.8270, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 13
# tensor(0.7825, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 14
# tensor(0.7743, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 15
# tensor(0.7919, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 16
# tensor(0.8144, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 17
# tensor(0.8098, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 18
# tensor(0.7929, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 19
# tensor(0.7698, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 20
# tensor(0.7401, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 21
# tensor(0.8078, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 22
# tensor(0.8075, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 23
# tensor(0.8204, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 24
# tensor(0.8128, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 25
# tensor(0.7426, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 26
# tensor(0.7574, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 27
# tensor(0.7799, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 28
# tensor(0.7720, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 29
# tensor(0.8100, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 30
# tensor(0.7962, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 31
# tensor(0.8069, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 32
# tensor(0.7729, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 33
# tensor(0.7919, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 34
# tensor(0.8169, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 35
# tensor(0.7849, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 36
# tensor(0.8375, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 37
# tensor(0.8101, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 38
# tensor(0.7972, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 2  batch: 39
# tensor(0.7854, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 0
# tensor(0.7801, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 1
# tensor(0.7325, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 2
# tensor(0.7574, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 3
# tensor(0.7840, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 4
# tensor(0.7777, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 5
# tensor(0.7787, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 6
# tensor(0.7545, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 7
# tensor(0.7435, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 8
# tensor(0.7759, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 9
# tensor(0.7746, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 10
# tensor(0.7505, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 11
# tensor(0.7317, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 12
# tensor(0.7734, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 13
# tensor(0.8086, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 14
# tensor(0.8037, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 15
# tensor(0.7786, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 16
# tensor(0.8010, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 17
# tensor(0.7655, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 18
# tensor(0.7138, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 19
# tensor(0.7720, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 20
# tensor(0.8230, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 21
# tensor(0.7413, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 22
# tensor(0.7743, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 23
# tensor(0.7881, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 24
# tensor(0.7569, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 25
# tensor(0.7799, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 26
# tensor(0.7762, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 27
# tensor(0.7596, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 28
# tensor(0.7919, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 29
# tensor(0.8004, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 30
# tensor(0.7692, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 31
# tensor(0.7686, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 32
# tensor(0.7878, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 33
# tensor(0.8082, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 34
# tensor(0.7437, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 35
# tensor(0.7283, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 36
# tensor(0.8760, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 37
# tensor(0.7857, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 38
# tensor(0.7859, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 3  batch: 39
# tensor(0.8092, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 0
# tensor(0.7354, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 1
# tensor(0.7825, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 2
# tensor(0.7628, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 3
# tensor(0.7534, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 4
# tensor(0.7832, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 5
# tensor(0.7641, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 6
# tensor(0.7634, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 7
# tensor(0.7193, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 8
# tensor(0.7315, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 9
# tensor(0.7629, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 10
# tensor(0.8049, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 11
# tensor(0.7583, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 12
# tensor(0.7339, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 13
# tensor(0.7784, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 14
# tensor(0.7969, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 15
# tensor(0.7733, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 16
# tensor(0.7689, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 17
# tensor(0.7684, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 18
# tensor(0.7408, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 19
# tensor(0.7515, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 20
# tensor(0.7925, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 21
# tensor(0.8038, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 22
# tensor(0.7263, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 23
# tensor(0.7409, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 24
# tensor(0.8155, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 25
# tensor(0.7315, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 26
# tensor(0.8339, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 27
# tensor(0.7944, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 28
# tensor(0.7611, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 29
# tensor(0.7982, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 30
# tensor(0.7819, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 31
# tensor(0.7662, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 32
# tensor(0.8210, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 33
# tensor(0.7923, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 34
# tensor(0.7460, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 35
# tensor(0.7440, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 36
# tensor(0.8126, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 37
# tensor(0.7442, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 38
# tensor(0.7994, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 4  batch: 39
# tensor(0.7539, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 0
# tensor(0.7381, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 1
# tensor(0.7152, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 2
# tensor(0.7712, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 3
# tensor(0.7675, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 4
# tensor(0.7316, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 5
# tensor(0.7843, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 6
# tensor(0.7708, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 7
# tensor(0.7869, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 8
# tensor(0.7500, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 9
# tensor(0.7750, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 10
# tensor(0.7695, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 11
# tensor(0.7680, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 12
# tensor(0.7387, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 13
# tensor(0.7950, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 14
# tensor(0.8020, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 15
# tensor(0.7514, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 16
# tensor(0.8090, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 17
# tensor(0.7646, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 18
# tensor(0.8328, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 19
# tensor(0.7864, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 20
# tensor(0.7752, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 21
# tensor(0.7805, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 22
# tensor(0.7578, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 23
# tensor(0.8159, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 24
# tensor(0.7432, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 25
# tensor(0.8167, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 26
# tensor(0.7808, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 27
# tensor(0.7766, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 28
# tensor(0.7837, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 29
# tensor(0.7630, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 30
# tensor(0.7803, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 31
# tensor(0.8223, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 32
# tensor(0.8060, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 33
# tensor(0.7615, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 34
# tensor(0.8082, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 35
# tensor(0.7525, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 36
# tensor(0.7568, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 37
# tensor(0.7812, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 38
# tensor(0.7133, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 5  batch: 39
# tensor(0.7435, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 0
# tensor(0.7471, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 1
# tensor(0.7465, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 2
# tensor(0.7401, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 3
# tensor(0.7756, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 4
# tensor(0.7450, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 5
# tensor(0.7394, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 6
# tensor(0.7182, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 7
# tensor(0.7659, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 8
# tensor(0.7616, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 9
# tensor(0.7380, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 10
# tensor(0.7696, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 11
# tensor(0.7162, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 12
# tensor(0.7603, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 13
# tensor(0.7156, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 14
# tensor(0.7805, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 15
# tensor(0.8022, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 16
# tensor(0.7052, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 17
# tensor(0.8609, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 18
# tensor(0.7831, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 19
# tensor(0.8139, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 20
# tensor(0.7714, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 21
# tensor(0.8438, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 22
# tensor(0.7680, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 23
# tensor(0.7492, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 24
# tensor(0.7464, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 25
# tensor(0.7583, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 26
# tensor(0.7533, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 27
# tensor(0.7585, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 28
# tensor(0.8050, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 29
# tensor(0.7464, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 30
# tensor(0.7954, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 31
# tensor(0.7389, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 32
# tensor(0.7665, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 33
# tensor(0.7777, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 34
# tensor(0.7287, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 35
# tensor(0.7793, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 36
# tensor(0.7439, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 37
# tensor(0.7536, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 38
# tensor(0.7237, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 6  batch: 39
# tensor(0.8387, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 0
# tensor(0.7304, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 1
# tensor(0.7285, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 2
# tensor(0.7357, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 3
# tensor(0.7888, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 4
# tensor(0.6929, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 5
# tensor(0.6921, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 6
# tensor(0.7345, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 7
# tensor(0.6817, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 8
# tensor(0.7582, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 9
# tensor(0.7263, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 10
# tensor(0.7698, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 11
# tensor(0.6576, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 12
# tensor(0.7776, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 13
# tensor(0.6939, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 14
# tensor(0.7747, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 15
# tensor(0.7257, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 16
# tensor(0.7795, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 17
# tensor(0.7467, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 18
# tensor(0.7751, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 19
# tensor(0.7856, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 20
# tensor(0.7674, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 21
# tensor(0.7624, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 22
# tensor(0.7863, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 23
# tensor(0.8211, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 24
# tensor(0.7748, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 25
# tensor(0.7731, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 26
# tensor(0.7575, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 27
# tensor(0.7629, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 28
# tensor(0.7985, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 29
# tensor(0.7668, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 30
# tensor(0.8111, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 31
# tensor(0.7855, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 32
# tensor(0.8181, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 33
# tensor(0.7601, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 34
# tensor(0.7618, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 35
# tensor(0.8438, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 36
# tensor(0.7348, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 37
# tensor(0.7723, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 38
# tensor(0.7353, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 7  batch: 39
# tensor(0.7191, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 0
# tensor(0.7173, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 1
# tensor(0.7514, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 2
# tensor(0.6700, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 3
# tensor(0.7055, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 4
# tensor(0.7458, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 5
# tensor(0.6946, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 6
# tensor(0.6675, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 7
# tensor(0.7290, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 8
# tensor(0.7344, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 9
# tensor(0.7529, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 10
# tensor(0.6913, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 11
# tensor(0.7488, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 12
# tensor(0.8339, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 13
# tensor(0.7510, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 14
# tensor(0.7273, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 15
# tensor(0.7503, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 16
# tensor(0.7748, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 17
# tensor(0.7932, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 18
# tensor(0.7602, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 19
# tensor(0.8227, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 20
# tensor(0.7674, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 21
# tensor(0.7582, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 22
# tensor(0.7277, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 23
# tensor(0.7968, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 24
# tensor(0.7491, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 25
# tensor(0.7550, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 26
# tensor(0.8024, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 27
# tensor(0.7628, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 28
# tensor(0.8032, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 29
# tensor(0.7635, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 30
# tensor(0.7750, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 31
# tensor(0.7889, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 32
# tensor(0.7327, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 33
# tensor(0.7642, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 34
# tensor(0.7718, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 35
# tensor(0.7812, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 36
# tensor(0.7724, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 37
# tensor(0.7494, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 38
# tensor(0.7263, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 8  batch: 39
# tensor(0.7034, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 0
# tensor(0.7331, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 1
# tensor(0.7128, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 2
# tensor(0.7062, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 3
# tensor(0.7285, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 4
# tensor(0.6939, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 5
# tensor(0.7582, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 6
# tensor(0.7203, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 7
# tensor(0.7582, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 8
# tensor(0.7383, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 9
# tensor(0.8037, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 10
# tensor(0.7296, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 11
# tensor(0.7595, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 12
# tensor(0.7461, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 13
# tensor(0.7308, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 14
# tensor(0.7659, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 15
# tensor(0.7591, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 16
# tensor(0.6999, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 17
# tensor(0.7403, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 18
# tensor(0.7359, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 19
# tensor(0.7726, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 20
# tensor(0.7479, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 21
# tensor(0.6967, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 22
# tensor(0.7159, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 23
# tensor(0.8304, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 24
# tensor(0.7977, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 25
# tensor(0.7304, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 26
# tensor(0.7540, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 27
# tensor(0.6942, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 28
# tensor(0.7363, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 29
# tensor(0.7545, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 30
# tensor(0.7618, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 31
# tensor(0.7592, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 32
# tensor(0.7044, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 33
# tensor(0.7199, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 34
# tensor(0.7294, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 35
# tensor(0.7638, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 36
# tensor(0.7364, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 37
# tensor(0.7272, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 38
# tensor(0.7580, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 9  batch: 39
# tensor(0.7937, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 0
# tensor(0.6612, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 1
# tensor(0.6840, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 2
# tensor(0.7205, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 3
# tensor(0.7630, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 4
# tensor(0.6888, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 5
# tensor(0.6875, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 6
# tensor(0.7116, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 7
# tensor(0.7146, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 8
# tensor(0.7230, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 9
# tensor(0.6934, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 10
# tensor(0.7541, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 11
# tensor(0.6935, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 12
# tensor(0.6982, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 13
# tensor(0.7287, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 14
# tensor(0.6993, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 15
# tensor(0.6983, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 16
# tensor(0.7717, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 17
# tensor(0.7346, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 18
# tensor(0.7051, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 19
# tensor(0.7171, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 20
# tensor(0.7403, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 21
# tensor(0.7555, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 22
# tensor(0.7629, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 23
# tensor(0.7545, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 24
# tensor(0.7477, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 25
# tensor(0.7726, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 26
# tensor(0.7393, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 27
# tensor(0.7160, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 28
# tensor(0.7036, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 29
# tensor(0.7175, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 30
# tensor(0.8092, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 31
# tensor(0.7067, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 32
# tensor(0.7262, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 33
# tensor(0.7400, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 34
# tensor(0.7483, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 35
# tensor(0.7971, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 36
# tensor(0.7576, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 37
# tensor(0.7544, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 38
# tensor(0.7534, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 10  batch: 39
# tensor(0.7326, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 0
# tensor(0.6852, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 1
# tensor(0.6931, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 2
# tensor(0.6414, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 3
# tensor(0.7443, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 4
# tensor(0.6821, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 5
# tensor(0.6600, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 6
# tensor(0.6991, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 7
# tensor(0.6876, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 8
# tensor(0.7581, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 9
# tensor(0.6458, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 10
# tensor(0.6874, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 11
# tensor(0.6773, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 12
# tensor(0.6415, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 13
# tensor(0.7560, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 14
# tensor(0.6918, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 15
# tensor(0.7399, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 16
# tensor(0.6972, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 17
# tensor(0.7499, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 18
# tensor(0.7007, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 19
# tensor(0.7590, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 20
# tensor(0.7381, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 21
# tensor(0.7029, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 22
# tensor(0.7614, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 23
# tensor(0.7166, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 24
# tensor(0.7613, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 25
# tensor(0.7579, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 26
# tensor(0.7620, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 27
# tensor(0.7736, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 28
# tensor(0.7647, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 29
# tensor(0.7374, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 30
# tensor(0.7559, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 31
# tensor(0.7283, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 32
# tensor(0.7049, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 33
# tensor(0.7227, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 34
# tensor(0.7204, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 35
# tensor(0.7169, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 36
# tensor(0.7362, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 37
# tensor(0.7206, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 38
# tensor(0.7711, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 11  batch: 39
# tensor(0.6861, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 0
# tensor(0.6856, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 1
# tensor(0.6627, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 2
# tensor(0.7760, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 3
# tensor(0.6494, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 4
# tensor(0.7139, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 5
# tensor(0.7377, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 6
# tensor(0.7259, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 7
# tensor(0.6826, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 8
# tensor(0.7772, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 9
# tensor(0.6589, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 10
# tensor(0.7407, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 11
# tensor(0.7333, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 12
# tensor(0.6827, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 13
# tensor(0.6825, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 14
# tensor(0.6486, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 15
# tensor(0.7017, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 16
# tensor(0.6807, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 17
# tensor(0.7154, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 18
# tensor(0.7093, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 19
# tensor(0.7468, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 20
# tensor(0.7166, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 21
# tensor(0.7701, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 22
# tensor(0.7018, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 23
# tensor(0.6956, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 24
# tensor(0.7187, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 25
# tensor(0.7555, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 26
# tensor(0.6955, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 27
# tensor(0.7563, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 28
# tensor(0.7110, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 29
# tensor(0.7534, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 30
# tensor(0.7156, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 31
# tensor(0.7546, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 32
# tensor(0.7341, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 33
# tensor(0.7377, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 34
# tensor(0.7356, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 35
# tensor(0.7106, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 36
# tensor(0.7341, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 37
# tensor(0.7333, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 38
# tensor(0.6725, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 12  batch: 39
# tensor(0.6329, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 0
# tensor(0.7023, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 1
# tensor(0.6382, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 2
# tensor(0.6460, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 3
# tensor(0.6393, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 4
# tensor(0.6529, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 5
# tensor(0.6769, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 6
# tensor(0.6760, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 7
# tensor(0.6731, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 8
# tensor(0.6790, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 9
# tensor(0.6870, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 10
# tensor(0.6700, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 11
# tensor(0.6705, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 12
# tensor(0.6979, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 13
# tensor(0.6414, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 14
# tensor(0.6738, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 15
# tensor(0.6830, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 16
# tensor(0.6924, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 17
# tensor(0.6838, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 18
# tensor(0.6685, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 19
# tensor(0.7351, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 20
# tensor(0.6760, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 21
# tensor(0.7113, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 22
# tensor(0.6997, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 23
# tensor(0.6926, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 24
# tensor(0.6992, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 25
# tensor(0.7553, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 26
# tensor(0.7122, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 27
# tensor(0.7029, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 28
# tensor(0.7170, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 29
# tensor(0.7125, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 30
# tensor(0.6943, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 31
# tensor(0.7009, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 32
# tensor(0.7621, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 33
# tensor(0.7690, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 34
# tensor(0.7091, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 35
# tensor(0.7396, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 36
# tensor(0.8060, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 37
# tensor(0.7099, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 38
# tensor(0.7485, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 13  batch: 39
# tensor(0.7677, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 0
# tensor(0.6709, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 1
# tensor(0.6867, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 2
# tensor(0.6234, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 3
# tensor(0.6083, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 4
# tensor(0.6299, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 5
# tensor(0.6547, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 6
# tensor(0.6359, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 7
# tensor(0.6577, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 8
# tensor(0.6542, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 9
# tensor(0.6730, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 10
# tensor(0.6708, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 11
# tensor(0.6977, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 12
# tensor(0.6981, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 13
# tensor(0.6853, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 14
# tensor(0.6861, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 15
# tensor(0.6832, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 16
# tensor(0.6666, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 17
# tensor(0.6669, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 18
# tensor(0.6586, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 19
# tensor(0.6464, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 20
# tensor(0.6877, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 21
# tensor(0.6695, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 22
# tensor(0.7199, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 23
# tensor(0.6761, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 24
# tensor(0.7032, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 25
# tensor(0.6815, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 26
# tensor(0.6856, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 27
# tensor(0.6843, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 28
# tensor(0.6856, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 29
# tensor(0.6842, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 30
# tensor(0.7258, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 31
# tensor(0.7216, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 32
# tensor(0.7107, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 33
# tensor(0.7253, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 34
# tensor(0.6813, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 35
# tensor(0.7821, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 36
# tensor(0.7423, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 37
# tensor(0.7114, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 38
# tensor(0.7488, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 14  batch: 39
# tensor(0.6825, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 15  batch: 0
# tensor(0.6352, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 15  batch: 1
# tensor(0.6793, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 15  batch: 2
# tensor(0.6392, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 15  batch: 3
# tensor(0.6562, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 15  batch: 4
# tensor(0.6237, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 15  batch: 5
# ...
# tensor(0.5912, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 1
# tensor(0.5984, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 2
# tensor(0.5859, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 3
# tensor(0.6035, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 4
# tensor(0.5794, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 5
# tensor(0.5490, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 6
# tensor(0.5778, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 7
# tensor(0.6050, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 8
# tensor(0.5401, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 9
# tensor(0.6178, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 10
# tensor(0.6422, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 11
# tensor(0.6155, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 12
# tensor(0.5902, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 13
# tensor(0.5850, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 14
# tensor(0.6216, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 15
# tensor(0.5616, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 16
# tensor(0.6088, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 17
# tensor(0.6311, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 18
# tensor(0.6014, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 19
# tensor(0.6362, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 20
# tensor(0.6093, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 21
# tensor(0.6263, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 22
# tensor(0.6096, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 23
# tensor(0.6004, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 24
# tensor(0.6623, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 25
# tensor(0.6370, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 26
# tensor(0.5899, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 27
# tensor(0.6299, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 28
# tensor(0.6143, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 29
# tensor(0.6088, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 30
# tensor(0.6601, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 31
# tensor(0.6398, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 32
# tensor(0.6343, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 33
# tensor(0.5825, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 34
# tensor(0.6188, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 35
# tensor(0.6772, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 36
# tensor(0.6636, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 37
# tensor(0.6494, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 38
# tensor(0.6441, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 55  batch: 39
# tensor(0.7237, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 0
# tensor(0.5580, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 1
# tensor(0.5581, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 2
# tensor(0.5436, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 3
# tensor(0.5600, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 4
# tensor(0.6043, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 5
# tensor(0.6215, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 6
# tensor(0.5799, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 7
# tensor(0.6260, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 8
# tensor(0.6028, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 9
# tensor(0.6417, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 10
# tensor(0.6178, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 11
# tensor(0.6315, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 12
# tensor(0.6025, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 13
# tensor(0.6082, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 14
# tensor(0.6138, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 15
# tensor(0.6101, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 16
# tensor(0.6063, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 17
# tensor(0.6601, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 18
# tensor(0.5688, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 19
# tensor(0.5963, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 20
# tensor(0.5962, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 21
# tensor(0.5908, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 22
# tensor(0.6197, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 23
# tensor(0.6546, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 24
# tensor(0.6352, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 25
# tensor(0.6406, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 26
# tensor(0.6742, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 27
# tensor(0.6322, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 28
# tensor(0.6353, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 29
# tensor(0.6534, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 30
# tensor(0.6181, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 31
# tensor(0.6333, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 32
# tensor(0.6032, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 33
# tensor(0.6514, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 34
# tensor(0.6461, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 35
# tensor(0.6271, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 36
# tensor(0.6180, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 37
# tensor(0.6321, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 38
# tensor(0.6003, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 56  batch: 39
# tensor(0.6850, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 0
# tensor(0.6101, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 1
# tensor(0.5946, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 2
# tensor(0.6549, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 3
# tensor(0.6021, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 4
# tensor(0.5816, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 5
# tensor(0.5955, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 6
# tensor(0.6450, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 7
# tensor(0.5469, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 8
# tensor(0.5404, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 9
# tensor(0.5500, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 10
# tensor(0.5664, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 11
# tensor(0.5871, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 12
# tensor(0.5858, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 13
# tensor(0.5785, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 14
# tensor(0.6212, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 15
# tensor(0.5694, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 16
# tensor(0.6060, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 17
# tensor(0.5972, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 18
# tensor(0.6044, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 19
# tensor(0.5836, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 20
# tensor(0.6014, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 21
# tensor(0.6288, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 22
# tensor(0.6459, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 23
# tensor(0.6388, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 24
# tensor(0.6060, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 25
# tensor(0.6364, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 26
# tensor(0.6057, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 27
# tensor(0.6732, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 28
# tensor(0.6411, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 29
# tensor(0.6026, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 30
# tensor(0.6502, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 31
# tensor(0.6257, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 32
# tensor(0.6298, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 33
# tensor(0.6497, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 34
# tensor(0.6487, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 35
# tensor(0.6357, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 36
# tensor(0.6828, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 37
# tensor(0.6977, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 38
# tensor(0.7011, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 57  batch: 39
# tensor(0.6424, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 0
# tensor(0.5689, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 1
# tensor(0.5751, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 2
# tensor(0.5799, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 3
# tensor(0.5964, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 4
# tensor(0.5988, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 5
# tensor(0.5922, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 6
# tensor(0.5775, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 7
# tensor(0.5601, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 8
# tensor(0.5892, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 9
# tensor(0.5916, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 10
# tensor(0.5827, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 11
# tensor(0.5674, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 12
# tensor(0.5827, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 13
# tensor(0.6187, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 14
# tensor(0.5980, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 15
# tensor(0.5995, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 16
# tensor(0.5873, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 17
# tensor(0.6283, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 18
# tensor(0.6182, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 19
# tensor(0.6008, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 20
# tensor(0.5884, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 21
# tensor(0.6137, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 22
# tensor(0.6099, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 23
# tensor(0.5947, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 24
# tensor(0.6023, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 25
# tensor(0.6341, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 26
# tensor(0.6206, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 27
# tensor(0.5954, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 28
# tensor(0.6062, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 29
# tensor(0.6170, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 30
# tensor(0.6238, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 31
# tensor(0.6453, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 32
# tensor(0.6337, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 33
# tensor(0.6257, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 34
# tensor(0.6576, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 35
# tensor(0.6815, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 36
# tensor(0.6825, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 37
# tensor(0.6732, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 38
# tensor(0.6508, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 58  batch: 39
# tensor(0.6579, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 0
# tensor(0.5519, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 1
# tensor(0.5758, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 2
# tensor(0.5669, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 3
# tensor(0.5894, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 4
# tensor(0.5650, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 5
# tensor(0.5648, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 6
# tensor(0.6173, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 7
# tensor(0.5894, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 8
# tensor(0.5701, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 9
# tensor(0.5741, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 10
# tensor(0.5880, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 11
# tensor(0.5785, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 12
# tensor(0.6242, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 13
# tensor(0.5795, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 14
# tensor(0.5895, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 15
# tensor(0.6026, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 16
# tensor(0.5968, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 17
# tensor(0.5726, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 18
# tensor(0.5807, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 19
# tensor(0.6062, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 20
# tensor(0.6098, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 21
# tensor(0.6058, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 22
# tensor(0.6430, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 23
# tensor(0.6100, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 24
# tensor(0.6320, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 25
# tensor(0.6450, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 26
# tensor(0.6221, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 27
# tensor(0.6967, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 28
# tensor(0.6274, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 29
# tensor(0.6481, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 30
# tensor(0.6471, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 31
# tensor(0.6762, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 32
# tensor(0.6853, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 33
# tensor(0.6736, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 34
# tensor(0.6273, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 35
# tensor(0.6465, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 36
# tensor(0.6647, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 37
# tensor(0.6521, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 38
# tensor(0.6138, device='cuda:0', grad_fn=<MseLossBackward>)
# epoch: 59  batch: 39
# tensor(0.6975, device='cuda:0', grad_fn=<MseLossBackward>)
# tensor(0.7562, device='cuda:0', grad_fn=<MseLossBackward>)
